# %% [markdown]
# Step 2: Establish a dataset with both stock and sentiment

# %%
import datetime
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from transformers import BertTokenizer, BertModel
from transformers import get_linear_schedule_with_warmup
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
from torch.optim import AdamW
import sys 
import os
sys.path.append(os.path.abspath("/Users/13793/Desktop/aas/stock"))
import yfinance as yf
import matplotlib.pyplot as plt

# Add the project root directory to the Python path
import subprocess
result = subprocess.check_output(["git", "rev-parse", "--show-toplevel"], universal_newlines=True)
git_root = result.strip()
sys.path.append(git_root)

import processer as processer

# %% [markdown]
# Prepare Sentiment Data

# %%
#Set up for BERT
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased', do_lower_case = True)
MAX_LEN = 50

# %%
#BERT processing function setup
def prep(data):
    input_ids = []
    attention_masks = []
    
    for i in data:
        encoding = tokenizer.encode_plus(
                text=i, 
                add_special_tokens=True, 
                padding='max_length', 
                max_length = MAX_LEN, 
                truncation=True, 
                return_tensors="pt", 
                return_attention_mask=True )

        input_ids.append(encoding.get('input_ids'))
        attention_masks.append(encoding.get('attention_mask'))
    
    input_ids = torch.concat(input_ids)
    attention_masks = torch.concat(attention_masks)
    
    return input_ids, attention_masks

# %%
# Define the Bert NLP Classifier
class BertClassifier(nn.Module):
    def __init__(self, freeze=False):
        super(BertClassifier, self).__init__()
        input_layer = 768
        hidden_layer = 40
        output_layer = 2

        self.bert = BertModel.from_pretrained('bert-base-uncased')

        self.classifier = nn.Sequential(
            nn.Linear(input_layer, hidden_layer), 
            nn.ReLU(), 
            nn.Linear(hidden_layer, output_layer))

        if freeze:
            for i in self.bert.parameters():
                i.requires_grad = False
        
    def forward(self, input_ids, attention_mask):
        outputs = self.bert(input_ids, attention_mask)
        layer = outputs[0][:, 0, :]
        logits = self.classifier(layer)

        return logits

# %%
# Check if GPU is available and assign device 
if torch.cuda.is_available():       
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
model = BertClassifier(freeze=False)
model.load_state_dict(torch.load('stock_sentiment_model.pt'))
model.to(device)
# Out:
# BertClassifier(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSdpaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=768, out_features=40, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=40, out_features=2, bias=True)
#   )
# )

# %%
stocks = pd.read_csv("hf://datasets/nbettencourt/SC454k/sc454k_clean.csv")
# Out:
# 'HTTPSConnectionPool(host='cdn-lfs-us-1.huggingface.co', port=443): Read timed out.' thrown while requesting GET https://huggingface.co/datasets/nbettencourt/SC454k/resolve/main/sc454k_clean.csv
# Retrying in 1s [Retry 1/5].
# '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: be620d7a-5fbb-4911-99a2-d1a82a80009e)')' thrown while requesting GET https://huggingface.co/datasets/nbettencourt/SC454k/resolve/main/sc454k_clean.csv
# Retrying in 2s [Retry 2/5].

# %%
substrings = ['AAPL', 'COST', 'AMZN', 'DIS', 'GOOGL', 'JPM', 'LLY', 'MSFT', 'META', 'NFLX', 'NVDA', 'TSLA']
pattern = '|'.join(substrings)

stock = stocks[stocks['Article'].str.contains(pattern, case=False, na=False)]
stock
# Out:
#         Unnamed: 0 Symbol                   Security  \
# 1                1    AAN  The Aaron's Company, Inc.
# 2                2    AAN  The Aaron's Company, Inc.
# 3                3    AAN  The Aaron's Company, Inc.
# 4                4    AAN  The Aaron's Company, Inc.
# 5                5    AAN  The Aaron's Company, Inc.
# ...            ...    ...                        ...
# 453926      453926   ZYME             Zymeworks Inc.
# 453927      453927   ZYME             Zymeworks Inc.
# 453928      453928   ZYME             Zymeworks Inc.
# 453929      453929   ZYME             Zymeworks Inc.
# 453930      453930   ZYME             Zymeworks Inc.
#
#                                                       URL  \
# 1       https://www.nasdaq.com/press-release/the-aaron...
# 2       https://www.nasdaq.com/articles/why-is-aarons-...
# 3       https://www.nasdaq.com/articles/3-retail-stock...
# 4       https://www.nasdaq.com/articles/aarons-aan-bra...
# 5       https://www.nasdaq.com/articles/aarons-company...
# ...                                                   ...
# 453926  https://www.nasdaq.com/articles/shareholders-h...
# 453927  https://www.nasdaq.com/articles/best-biotech-s...
# 453928  https://www.nasdaq.com/press-release/independe...
# 453929  https://www.nasdaq.com/articles/cancer-results...
# 453930  https://www.nasdaq.com/articles/denali-therape...
#
#                             Date         RelatedStocksList  \
# 1       Apr 01, 2022 10:13 AM ET                       NaN
# 2       Apr 02, 2023 02:24 AM ET                Technology
# 3       Apr 04, 2019 06:08 AM ET  TGT|Markets|BBY|WMT|AMZN
# 4       Apr 04, 2022 03:50 PM ET       Stocks|COLM|GIL|DLA
# 5       Apr 04, 2024 06:54 PM ET                    Stocks
# ...                          ...                       ...
# 453926  Sep 17, 2021 11:33 AM ET          Public Companies
# 453927  Sep 18, 2021 06:33 AM ET  PFE|Stocks|MRNA|ABCL|JNJ
# 453928  Sep 26, 2022 04:17 PM ET                       NaN
# 453929  Sep 27, 2019 01:54 PM ET        Markets|AMGN|RHHBY
# 453930  Sep 29, 2022 08:25 AM ET               Stocks|DNLI
#
#                                                   Article  \
# 1       ATLANTA, April 1, 2022 PRNewswire/ --  The Aar...
# 2       It has been about a month since the last earni...
# 3       The S&P 500 has climbed nearly 15% this year, ...
# 4       **The Aaron's Company, Inc.** [AAN](https://ww...
# 5       Aaron's Company, Inc. (AAN) closed the latest ...
# ...                                                   ...
# 453926  The worst result, after buying shares in a com...
# 453927  **4 Top Biotech Stocks To Watch This Upcoming ...
# 453928  - Institutional Shareholder Services joins Gla...
# 453929  Several times a year, leading cancer researche...
# 453930  Denali Therapeutics Inc. (DNLI) shares ended t...
#
#                                                     Title    articleType  \
# 1       THE AARON'S COMPANY COMPLETES ACQUISITION OF B...  Press Release
# 2       Why Is Aaron's (AAN) Down 26.3% Since Last Ear...           News
# 3       3 Retail Stocks to Buy Right Now for Value & I...           News
# 4       Aaron's (AAN) BrandsMart Buyout to Boost Sales...           News
# 5       Aaron's Company, Inc. (AAN) Stock Moves -0.27%...           News
# ...                                                   ...            ...
# 453926  Shareholders have faith in loss-making Zymewor...           News
# 453927  Best Biotech Stocks To Buy Now? 4 For Your Wat...           News
# 453928  Independent Proxy Advisory Firm ISS Recommends...  Press Release
# 453929  Cancer Results to Watch at This Weekend’s Euro...           News
# 453930  Denali Therapeutics Inc. (DNLI) Moves 17.7% Hi...           News
#
#                  Publication                 Author
# 1       Symbol Press Release                 Symbol
# 2                      Zacks  Zacks Equity Research
# 3                      Zacks                    NaN
# 4                      Zacks  Zacks Equity Research
# 5                      Zacks  Zacks Equity Research
# ...                      ...                    ...
# 453926        Simply Wall St         Simply Wall St
# 453927       StockMarket.com            Brett David
# 453928  Symbol Press Release                 Symbol
# 453929       The Motley Fool             David Haen
# 453930                 Zacks  Zacks Equity Research
#
# [390358 rows x 11 columns]

# %%
# Get the list of stock data to convert
stock['Datetime'] = pd.to_datetime(stock['Date'])

    # Rename column that holds the tweets content to aligh with previous model
stock.rename(columns = {'Article':'Text'}, inplace = True)

    # Pre process the tweet content
stock = processer.Preprocess_Tweets(stock)

    # Remove excess columns
stock = stock[['Text', 'Symbol', 'Datetime']]
    
stock = stock.fillna(0)

stock_inputs, stock_masks = prep(stock['Text'].values)

batch_size = 16
stock_data = TensorDataset(stock_inputs, stock_masks)
stock_sampler = RandomSampler(stock_data)
stock_dataloader = DataLoader(stock_data, sampler=stock_sampler, batch_size=batch_size)

model.eval()

predictions = []
    # Hidden Feature: Use the ratio of Logits to classify if it the pos/neg is strong or weak, discarded due to no significant improvement
    #log1 = []
    #log2 = []
for batch in stock_dataloader:
        # Get encoded inputs and masks 
    batch_inputs, batch_masks = batch

        # Send variables to device (GPU if available)
    batch_inputs = batch_inputs.to(device)
    batch_masks = batch_masks.to(device)

        # Predict classes with Bert for given inputs 
    with torch.no_grad():
        logits = model(batch_inputs, batch_masks)

        # Convert predictions to 0s and 1s
    preds = torch.argmax(logits, dim=1).flatten()
    predictions.append(preds)
        #log1.append(logits[:,0])
        #log2.append(logits[:,1])
    # Combine all batch predictions
predictions = torch.cat(predictions).cpu().numpy()
    #log1 = torch.cat(log1).cpu().numpy()
    #log2 = torch.cat(log2).cpu().numpy()

    # Add predictions to stock dataframe
stock['Sentiment'] = predictions
    #stock['log1'] = log1
    #stock['log2'] = log2
    
    # save predictions as new csv    
    # Show each stock completed
# Out:
# C:\Users\13793\AppData\Local\Temp\ipykernel_18116\3979439249.py:2: FutureWarning: Parsed string "Apr 01, 2022 10:13 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   stock['Datetime'] = pd.to_datetime(stock['Date'])
# C:\Users\13793\AppData\Local\Temp\ipykernel_18116\3979439249.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock['Datetime'] = pd.to_datetime(stock['Date'])
# C:\Users\13793\AppData\Local\Temp\ipykernel_18116\3979439249.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock.rename(columns = {'Article':'Text'}, inplace = True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.lower()
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'https?:\/\/.*[\r\n]*', ' ',regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'www.*[\r\n]*', ' ',regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('https', '', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace(': ', ' ', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace(', ', ' ', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('. ', ' ', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('[;\n~]', ' ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace("[]'â€¦*™|]", '', regex=True)
# c:\Users\13793\anaconda3\Lib\site-packages\pandas\core\strings\object_array.py:172: FutureWarning: Possible nested set at position 1
#   pat = re.compile(pat, flags=flags)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('[[()!?"]', '', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('_', '', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('w/', ' with ', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('f/', ' for ', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace(':)', '', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace(':-)', '', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace(':(', '', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace(':-(', '', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('0_o', '', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace(';)', '', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('=^.^=', '', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('%', ' percent ', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace(' & ', ' and ', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('&amp', ' and ', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('&gt', ' greater than ', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('cup&handle', 'cup and handle', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('c&h', 'cup and handle', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('head&shoulders', 'head and shoulders', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('h&s', 'head and shoulders', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('point&figure', 'point and figure', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('p&f', 'point and figure', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('s&p', 'SP500', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('q&a', 'question and answer', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('&', ' and ', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('@[a-z0-9]+', '', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('#[a-z0-9]+', '', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('@', '', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('#', '', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'([a-z]),([a-z])', r'\1 \2', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'([0-9]),([0-9])', r'\1\2', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'([0-9])[+]+', r'\1 ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace(',', '', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('u.s.', ' us ', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('\.{2,}', ' ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'([a-z])\.([a-z])', r'\1 \2', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('pdating', 'updating', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'([a-z])\.', r'\1 ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'\.([a-z])', r' \1', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace(' . ', ' ', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'[+]([0-9])', r'positive \1', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:80: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('c+h', 'cup and handle', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:81: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('h+s', 'head and shoulders', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('cup+handle', 'cup and handle', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace(' + ', ' and ', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('+ ', ' ', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'([a-z])[+]([a-z])', r'\1 and \2', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('+', '', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'([a-z])[-]+([a-z])', r'\1 \2', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'([a-z]) - ([a-z])', r'\1 to \2', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'([0-9]) -([0-9\.])', r'\1 to \2', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:95: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r' [-]([0-9])', r' negative \1', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'([0-9])-([0-9\.])', r'\1 to \2', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'([0-9]) - ([0-9\.])', r'\1 to \2', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'([0-9a-z])-([0-9a-z])', r'\1 \2', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('[-]+[>]', ' ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace(' [-]+ ', ' ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('-', ' ', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('[$][0-9\.]', ' dollars ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:107: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('$', '', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('=', ' equals ', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:115: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('b/c', ' because ', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:116: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('b/out', ' break out ', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('b/o', ' break out ', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:118: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('p/e', ' pe ratio ', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:119: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace(' [/]+ ', ' ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:120: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace(' 1/2 ', ' .5 ', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace(' 1/4 ', ' .25 ', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:122: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace(' 3/4 ', ' .75 ', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:123: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace(' 1/3 ', ' .3 ', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace(' 2/3 ', ' .6 ', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:126: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('[/]{2,}', ' ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:127: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'([a-z])/([a-z])', r'\1 and \2', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('[0-9]+/[0-9]+/[0-9]+', '', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'([0-9]{3,})/([0-9\.]{2,})', r'\1 to \2', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'([0-9]{2,})/([0-9\.]{3,})', r'\1 to \2', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('[a-z0-9]+/[a-z0-9]+', ' ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('/', '', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:137: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('[<]+ ', ' ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:138: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('<', ' less than ', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace(' [>]+', ' ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('>', ' greater than ', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('[0-9]+:[0-9]+am', ' ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:145: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('[0-9]+:[0-9]', ' ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace(':', ' ', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('user ', ' ', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:152: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'([0-9]+)dma', r'\1 displaced moving average ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:153: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'dma([0-9]+)', r'\1 displaced moving average ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:154: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'([0-9]+)sma', r'\1 simple moving average ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:155: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'sma([0-9]+)', r'\1 simple moving average ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:156: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'([0-9]+)ema', r'\1 expontential moving average ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:157: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'ema([0-9]+)', r'\1 expontential moving average ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'([0-9]+)ma', r'\1 moving average ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:159: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'ma([0-9]+)', r'\1 moving average ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:161: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'([0-9])mos', r'\1 months ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:162: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'([0-9])minute', r'\1 minute ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'([0-9])minutes', r'\1 minutes ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:164: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'([0-9])min', r'\1 minute ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:165: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'([0-9])mins', r'\1 minutes ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:166: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'([0-9])day', r'\1 day ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:167: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'([0-9])days', r'\1 days ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'([0-9])wk', r'\1 week ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:169: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace(' wk ', ' week ', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...
#   data['Text'] = data['Text'].str.replace(' ppl', ' people ', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:193: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace(' pts', ' points ', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace(' pt', ' point ', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:195: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace(' l(ol){1,}', ' laugh ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:196: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('imho', ' in my opinion ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace('prev ', 'previous ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:200: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace(' 1q', ' first quarter ', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:201: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace(' 2q', ' second quarter ', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace(' 3q', ' third quarter ', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:203: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace(' 4q', ' fourth quarter ', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace(' q1', ' first quarter ', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace(' q2', ' second quarter ', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:206: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace(' q3', ' third quarter ', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:207: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace(' q4', ' fourth quarter ', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:208: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace(' 10q ', ' form 10 ', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'([0-9])million', r'\1 million ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:211: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'([0-9])mil', r'\1 million ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:212: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace(' mil ', ' million ', regex=False)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'([0-9])billion', r'\1 billion ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:214: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'([0-9])cents', r'\1 cents ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:216: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'([0-9])3d', r'\1 3 dimensional ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:217: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'([0-9])gb', r'\1 3 gigabytes ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:221: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'([0-9])c', r'\1 calls ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:222: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'([0-9])y', r'\1 year ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:223: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'([0-9])p', r'\1 puts ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:224: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'([0-9])d', r'\1 days ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:225: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'([0-9])h', r'\1 hour ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:226: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'([0-9])s', r'\1 ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:227: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'([0-9])k1', r'\1 thousand ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:228: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'([0-9])k', r'\1 thousand ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:229: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'([0-9])m', r'\1 million ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:230: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'([0-9])b', r'\1 billion ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:233: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].replace(r'([0-9])([a-z])', r'\1 \2', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:236: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.replace(' +', ' ', regex=True)
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:237: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.strip(' .!?,)(:-')
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:240: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].apply(lambda s: " ".join([word for word in s.split() if word not in Stop]))
# c:\Users/13793/Desktop/aas/Portfolio\processer.py:241: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Text'] = data['Text'].str.strip()
# c:\Users\13793\anaconda3\Lib\site-packages\transformers\models\bert\modeling_bert.py:435: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at ..\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:455.)
#   attn_output = torch.nn.functional.scaled_dot_product_attention(
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 56
#      51 stock['Sentiment'] = predictions
#      52     #stock['log1'] = log1
#      53     #stock['log2'] = log2
#      54
#      55     # save predictions as new csv
# ---> 56 stock.to_csv('data/'+files[x] +'/stock_data_sentiment.csv', index=False)
#
# NameError: name 'files' is not defined

# %%
stock
stock.to_csv('stock_data_sentiment.csv', index=False)

# %% [markdown]
# Merge with stock data
